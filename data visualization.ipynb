# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/clean.csv')

# %%
df.describe()
# Out:
#        ProductionBudget  WorldwideGross
# count      5.500000e+03    5.500000e+03
# mean       3.389609e+07    1.012848e+08
# std        4.274083e+07    1.867703e+08
# min        1.100000e+03    4.010000e+02
# 25%        6.500000e+06    8.200095e+06
# 50%        2.000000e+07    3.503742e+07
# 75%        4.300000e+07    1.089669e+08
# max        4.000000e+08    2.845900e+09

# %%
X = pd.DataFrame(df, columns=['ProductionBudget'])
y = pd.DataFrame(df, columns=['WorldwideGross'])

# %%
plt.figure(figsize= (16, 9))
plt.scatter(X,y, alpha= 0.5)
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.xlabel("Production Budget (in USD)")
plt.ylabel("Worldwide Gross (in USD)")
plt.title("Film Cost vs Global Revenue")
plt.show()
